# %%
# !pip install -i https://test.pypi.org/simple/ agh-unit-converter-Man1ek27

# %%
from unit_converter.converter import meters_to_kilometers

m = 1500
km = meters_to_kilometers(m)
print(f"{m} metrów to {km} kilometrów.")
